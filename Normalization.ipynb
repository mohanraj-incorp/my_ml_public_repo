# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import pandas as pd
import seaborn as sns
sns.set_theme()
from scipy import stats

# %%
import numpy as np

 
# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt
 
# generate non-normal data (exponential)
original_data = np.random.exponential(size = 1000)
 
# transform training data & save lambda value
fitted_data, fitted_lambda = stats.boxcox(original_data)
 
# creating axes to draw plots
fig, ax = plt.subplots(1, 2)
 
# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(original_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = ax[0])
 
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")
 
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\3712338083.py:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(original_data, hist = False, kde = True,
# C:\Users\Sowmya\anaconda3\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\3712338083.py:23: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
df_housing = pd.read_csv(r"datasets\Normalization_houseprices.csv")

# %%
df_housing.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %%
df_housing['Box_Cox_Sqft_living'],f= stats.boxcox(df_housing['sqft_living'])
print(f)
# Out:
# 0.03764204225238658

# %%
sns.distplot(df_housing['sqft_living'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\1382429669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing['sqft_living'])

# %%
sns.distplot(df_housing['Box_Cox_Sqft_living'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\666460886.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing['Box_Cox_Sqft_living'])

# %%
sns.distplot(df_housing['price'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\270754077.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing['price'])

# %%
df_housing['Box_Cox_price'],f= stats.boxcox(df_housing['price']+10)
print(f)
# Out:
# 0.35995709382451996

# %%
sns.distplot(df_housing['Box_Cox_price'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\2216006791.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing['Box_Cox_price'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df_housing_scaled = scaler.fit_transform(df_housing[['sqft_lot', 'sqft_living']].to_numpy())
df_housing_scaled = pd.DataFrame(df_housing_scaled, columns=['sqft_lot', 'sqft_living'])

# %%
df_housing_scaled.head(10)
# Out:
#    sqft_lot  sqft_living
# 0  0.006775     0.073652
# 1  0.007835     0.249051
# 2  0.010534     0.118451
# 3  0.006885     0.123766
# 4  0.009186     0.119210
# 5  0.005348     0.038724
# 6  0.001790     0.074412
# 7  0.032815     0.177677
# 8  0.081771     0.156416
# 9  0.005181     0.087320

# %%
sns.distplot(df_housing['sqft_lot'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\3796251839.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing['sqft_lot'])

# %%
sns.distplot(df_housing_scaled['sqft_lot'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\3352694541.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing_scaled['sqft_lot'])

# %%
sns.distplot(df_housing['sqft_living'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\1382429669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing['sqft_living'])

# %%
sns.distplot(df_housing_scaled['sqft_living'])
plt.show()
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_10248\3121315156.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_housing_scaled['sqft_living'])
